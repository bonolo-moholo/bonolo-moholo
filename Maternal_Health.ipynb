# %% [markdown]
# <a href="https://colab.research.google.com/github/bonolo-moholo/bonolo-moholo/blob/main/Maternal_Health.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader.download("pregnancy scan", limit = 1000, output_dir = 'images', adult_filter_off = False)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [!!]Indexing page: 742
#
# [%] Indexed 19 Images on Page 742.
#
# ...
#
#
#
# [!!]Indexing page: 743
#
# [%] Indexed 19 Images on Page 743.
#
# ...
#
#
#
# [!!]Indexing page: 744
#
# [%] Indexed 19 Images on Page 744.
#
# ...
#
#
#
# [!!]Indexing page: 745
#
# [%] Indexed 19 Images on Page 745.
#
# ...
#
#
#
# [!!]Indexing page: 746
#
# [%] Indexed 19 Images on Page 746.
#
# ...
#
#
#
# [!!]Indexing page: 747
#
# [%] Indexed 19 Images on Page 747.
#
# ...
#
#
#
# [!!]Indexing page: 748
#
# [%] Indexed 19 Images on Page 748.
#
# ...
#
#
#
# [!!]Indexing page: 749
#
# [%] Indexed 19 Images on Page 749.
#
# ...
#
#
#
# [!!]Indexing page: 750
#
# [%] Indexed 19 Images on Page 750.
#
# ...
#
#
#
# [!!]Indexing page: 751
#
# [%] Indexed 19 Images on Page 751.
#
# ...
#
#
#
# [!!]Indexing page: 752
#
# [%] Indexed 19 Images on Page 752.
#
# ...
#
#
#
# [!!]Indexing page: 753
#
# [%] Indexed 19 Images on Page 753.
#
# ...
#
#
#
# [!!]Indexing page: 754
#
# [%] Indexed 19 Images on Page 754.
#
# ...
#
#
#
# ...
